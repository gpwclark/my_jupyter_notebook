# %%
init_radius = 1
half_radius = init_radius/2

c_init = circle((0,0), init_radius, rgbcolor=(255,255,255))

c = math.sqrt(math.pow(half_radius,2) + math.pow(half_radius,2))
sub_radius = 2 * c * 0.5

c_I = circle((half_radius, half_radius), sub_radius, rgbcolor=(255,255,255))
c_II = circle((-half_radius, half_radius), sub_radius, rgbcolor=(255,255,255))
c_III = circle((-half_radius, -half_radius), sub_radius, rgbcolor=(255,255,255))
c_IV = circle((half_radius, -half_radius), sub_radius, rgbcolor=(255,255,255))

show(c_init+ c_I + c_II + c_III + c_IV)

# This is a proof of concept for finding all the restaurants in a given initial radius
# with google API by querying an API again with a series of smaller circles (when the 
# initial query returns the max results and there is probably more restaurants in the
# radius than is reported).
# TODO
# 1. Figure out how to exclude a point if it is not inside the initial circle.
# 2. All of this will need to be done in meters but will need to be converted to/from
#    latitude and longitude. A series of helper functions should allow this computation
#    to be transparent.
# Out:
# Graphics object consisting of 5 graphics primitives
